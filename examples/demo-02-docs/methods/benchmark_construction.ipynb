# %% [markdown]
# # SR-Shift benchmark construction
#
# Builds topical and lexical splits. Temporal split TODO.

# %%
# TODO: seed not set
import random
random.seed(42)  # XXX actually this is set here but not in results_v3

# %%
# Topical split
# ... (code elided) ...

# %% [markdown]
# ## Temporal split
#
# TODO: implement — depends on timestamps from the news domain parser, which is stubbed out in methods/news_parser.py.
